# %%
import xarray as xr

# %%
ds = xr.open_zarr("/mnt/disks/gcp_data/pv_gsp/pvlive_gsp.zarr")

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                (datetime_gmt: 114144, gsp_id: 318)
# Coordinates:
#   * datetime_gmt           (datetime_gmt) datetime64[ns] 2018-01-01 ... 2024-...
#   * gsp_id                 (gsp_id) int64 0 1 2 3 4 5 ... 313 314 315 316 317
# Data variables:
#     capacity_mwp           (datetime_gmt, gsp_id) float64 dask.array<chunksize=(7134, 20), meta=np.ndarray>
#     generation_mw          (datetime_gmt, gsp_id) float64 dask.array<chunksize=(7134, 20), meta=np.ndarray>
#     installedcapacity_mwp  (datetime_gmt, gsp_id) float64 dask.array<chunksize=(7134, 20), meta=np.ndarray>
